# %%
import pandas as pd
from datetime import datetime
import os
import numpy as np

# %%
file = pd.read_csv(os.path.join("Data","Raw","America_Health_Rankings","2019-Annual.csv"))
print(file)
# Out:
#        Edition  Report Type                   Measure Name  \
# 0         2019  2019 Annual  Adverse Childhood Experiences
# 1         2019  2019 Annual  Adverse Childhood Experiences
# 2         2019  2019 Annual  Adverse Childhood Experiences
# 3         2019  2019 Annual  Adverse Childhood Experiences
# 4         2019  2019 Annual  Adverse Childhood Experiences
# 5         2019  2019 Annual  Adverse Childhood Experiences
# 6         2019  2019 Annual  Adverse Childhood Experiences
# 7         2019  2019 Annual  Adverse Childhood Experiences
# 8         2019  2019 Annual  Adverse Childhood Experiences
# 9         2019  2019 Annual  Adverse Childhood Experiences
# 10        2019  2019 Annual  Adverse Childhood Experiences
# 11        2019  2019 Annual  Adverse Childhood Experiences
# 12        2019  2019 Annual  Adverse Childhood Experiences
# 13        2019  2019 Annual  Adverse Childhood Experiences
# 14        2019  2019 Annual  Adverse Childhood Experiences
# ...

# %%
df2019 = pd.DataFrame(file)
df2019.head()
# Out:
#    Edition  Report Type                   Measure Name     State Name  Rank  \
# 0     2019  2019 Annual  Adverse Childhood Experiences         Alaska  34.0
# 1     2019  2019 Annual  Adverse Childhood Experiences        Alabama  46.0
# 2     2019  2019 Annual  Adverse Childhood Experiences  United States   NaN
# 3     2019  2019 Annual  Adverse Childhood Experiences       Arkansas  47.0
# 4     2019  2019 Annual  Adverse Childhood Experiences        Arizona  48.0
#
#    Value  Score  Lower CI  Upper CI  \
# 0   24.1   0.96      27.7      20.5
# 1   26.3   1.56      30.1      22.5
# 2   20.5    NaN      21.2      19.8
# 3   27.1   1.76      30.8      23.3
# 4   27.3   1.82      31.1      23.4
#
#                                               Source Source Year
# 0  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# 1  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# 2  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# ...

# %%
df2019.count()
# Out:
# Edition         32642
# Report Type     32642
# Measure Name    32642
# State Name      32642
# Rank            18950
# Value           27576
# Score           16803
# Lower CI        26006
# Upper CI        26006
# Source          32642
# Source Year     32486
# dtype: int64

# %%
df2019['Measure Name'].unique()
# Out:
# array(['Adverse Childhood Experiences', 'Air Pollution',
#        'All Determinants', 'All Outcomes', 'Behaviors',
#        'Below poverty threshold', 'Cancer Deaths',
#        'Cancer Deaths - American Indian/Alaska Native',
#        'Cancer Deaths - Asian/Pacific Islander',
#        'Cancer Deaths - Black/African American',
#        'Cancer Deaths - Crude Rate', 'Cancer Deaths - Female',
#        'Cancer Deaths - Hispanic/Latino', 'Cancer Deaths - Male',
#        'Cancer Deaths - Standard Age Adjustment', 'Cancer Deaths - White',
#        'Cardiovascular Deaths',
#        'Cardiovascular Deaths - American Indian/Alaska Native',
#        'Cardiovascular Deaths - Asian/Pacific Islander',
#        'Cardiovascular Deaths - Black/African American',
#        'Cardiovascular Deaths - Crude Rate',
#        'Cardiovascular Deaths - Female',
#        'Cardiovascular Deaths - Hispanic/Latino',
#        'Cardiovascular Deaths - Male',
# ...

# %%
#'Below poverty threshold','Cancer Deaths','Cardiovascular Deaths','Cholesterol Check','Diabetes','Drug Deaths',

# %%
Immunizations_Children=df2019[df2019['Measure Name']=='Immunizations - Children']

# %%
Immunizations_Children.head()
# Out:
#        Edition  Report Type              Measure Name     State Name  Rank  \
# 20062     2019  2019 Annual  Immunizations - Children         Alaska  32.0
# 20063     2019  2019 Annual  Immunizations - Children        Alabama  21.0
# 20064     2019  2019 Annual  Immunizations - Children  United States   NaN
# 20065     2019  2019 Annual  Immunizations - Children       Arkansas  34.0
# 20066     2019  2019 Annual  Immunizations - Children        Arizona  44.0
#
#        Value  Score  Lower CI  Upper CI  \
# 20062   69.5  -0.22      75.4      62.9
# 20063   71.2   0.20      77.6      64.0
# 20064   70.4    NaN      71.9      68.9
# 20065   69.4  -0.25      76.1      61.8
# 20066   66.5  -0.96      73.1      59.2
#
#                                         Source Source Year
# 20062  CDC, National Immunization Survey-Child        2017
# 20063  CDC, National Immunization Survey-Child        2017
# 20064  CDC, National Immunization Survey-Child        2017
# ...

# %%
Immunizations_Children.isnull().any()
# Out:
# Edition         False
# Report Type     False
# Measure Name    False
# State Name      False
# Rank             True
# Value           False
# Score            True
# Lower CI        False
# Upper CI        False
# Source          False
# Source Year     False
# dtype: bool

# %%
Immunizations_Children.loc[Immunizations_Children.isnull().any(axis=1)]
# Out:
#        Edition  Report Type              Measure Name            State Name  \
# 20064     2019  2019 Annual  Immunizations - Children         United States
# 20070     2019  2019 Annual  Immunizations - Children  District of Columbia
#
#        Rank  Value  Score  Lower CI  Upper CI  \
# 20064   NaN   70.4    NaN      71.9      68.9
# 20070   NaN   74.0    NaN      80.5      66.2
#
#                                         Source Source Year
# 20064  CDC, National Immunization Survey-Child        2017
# 20070  CDC, National Immunization Survey-Child        2017

# %%
Immunizations_Children = Immunizations_Children.fillna(value=0)
Immunizations_Children
# Out:
#        Edition  Report Type              Measure Name            State Name  \
# 20062     2019  2019 Annual  Immunizations - Children                Alaska
# 20063     2019  2019 Annual  Immunizations - Children               Alabama
# 20064     2019  2019 Annual  Immunizations - Children         United States
# 20065     2019  2019 Annual  Immunizations - Children              Arkansas
# 20066     2019  2019 Annual  Immunizations - Children               Arizona
# 20067     2019  2019 Annual  Immunizations - Children            California
# 20068     2019  2019 Annual  Immunizations - Children              Colorado
# 20069     2019  2019 Annual  Immunizations - Children           Connecticut
# 20070     2019  2019 Annual  Immunizations - Children  District of Columbia
# 20071     2019  2019 Annual  Immunizations - Children              Delaware
# 20072     2019  2019 Annual  Immunizations - Children               Florida
# ...

# %%
Immunizations_Children.count()
# Out:
# Edition         52
# Report Type     52
# Measure Name    52
# State Name      52
# Rank            52
# Value           52
# Score           52
# Lower CI        52
# Upper CI        52
# Source          52
# Source Year     52
# dtype: int64

# %%
list(Immunizations_Children.columns.values)
# Out:
# ['Edition',
#  'Report Type',
#  'Measure Name',
#  'State Name',
#  'Rank',
#  'Value',
#  'Score',
#  'Lower CI',
#  'Upper CI',
#  'Source',
#  'Source Year']

# %%
Immunizations_Children= Immunizations_Children[["State Name",
                                "Edition", 
                              "Measure Name",
                              "Rank",
                              "Value"]]

# %%
Immunizations_Children.head()
# Out:
#           State Name  Edition              Measure Name  Rank  Value
# 20062         Alaska     2019  Immunizations - Children  32.0   69.5
# 20063        Alabama     2019  Immunizations - Children  21.0   71.2
# 20064  United States     2019  Immunizations - Children   0.0   70.4
# 20065       Arkansas     2019  Immunizations - Children  34.0   69.4
# 20066        Arizona     2019  Immunizations - Children  44.0   66.5

# %%
Immunizations_Children.rename(columns = {'Rank' : 'Immunizations_Children_Rank', 
                             'Value' : 'Immunizations_Children_Value',
                            'State Name': 'State',
                            'Edition': 'Year'}, 
                  inplace = True)
# Out:
# C:\Users\steph\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
Immunizations_Children.head()
# Out:
#                State  Year              Measure Name  \
# 20062         Alaska  2019  Immunizations - Children
# 20063        Alabama  2019  Immunizations - Children
# 20064  United States  2019  Immunizations - Children
# 20065       Arkansas  2019  Immunizations - Children
# 20066        Arizona  2019  Immunizations - Children
#
#        Immunizations_Children_Rank  Immunizations_Children_Value
# 20062                         32.0                          69.5
# 20063                         21.0                          71.2
# 20064                          0.0                          70.4
# 20065                         34.0                          69.4
# 20066                         44.0                          66.5

# %%
Immunizations_Children = Immunizations_Children.drop('Measure Name',axis=1)

# %%
Immunizations_Children.head()
# Out:
#                State  Year  Immunizations_Children_Rank  \
# 20062         Alaska  2019                         32.0
# 20063        Alabama  2019                         21.0
# 20064  United States  2019                          0.0
# 20065       Arkansas  2019                         34.0
# 20066        Arizona  2019                         44.0
#
#        Immunizations_Children_Value
# 20062                          69.5
# 20063                          71.2
# 20064                          70.4
# 20065                          69.4
# 20066                          66.5

# %%
Immunizations_Children.to_csv(os.path.join("Data","Raw","America_Health_Rankings","2019 MidStep","Immunizations_Children.csv"),index = False)
