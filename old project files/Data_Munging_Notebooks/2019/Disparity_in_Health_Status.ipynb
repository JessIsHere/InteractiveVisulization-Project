# %%
import pandas as pd
from datetime import datetime
import os
import numpy as np

# %%
file = pd.read_csv(os.path.join("Data","Raw","America_Health_Rankings","2019-Annual.csv"))
print(file)
# Out:
#        Edition  Report Type                   Measure Name  \
# 0         2019  2019 Annual  Adverse Childhood Experiences
# 1         2019  2019 Annual  Adverse Childhood Experiences
# 2         2019  2019 Annual  Adverse Childhood Experiences
# 3         2019  2019 Annual  Adverse Childhood Experiences
# 4         2019  2019 Annual  Adverse Childhood Experiences
# 5         2019  2019 Annual  Adverse Childhood Experiences
# 6         2019  2019 Annual  Adverse Childhood Experiences
# 7         2019  2019 Annual  Adverse Childhood Experiences
# 8         2019  2019 Annual  Adverse Childhood Experiences
# 9         2019  2019 Annual  Adverse Childhood Experiences
# 10        2019  2019 Annual  Adverse Childhood Experiences
# 11        2019  2019 Annual  Adverse Childhood Experiences
# 12        2019  2019 Annual  Adverse Childhood Experiences
# 13        2019  2019 Annual  Adverse Childhood Experiences
# 14        2019  2019 Annual  Adverse Childhood Experiences
# ...

# %%
df2019 = pd.DataFrame(file)
df2019.head()
# Out:
#    Edition  Report Type                   Measure Name     State Name  Rank  \
# 0     2019  2019 Annual  Adverse Childhood Experiences         Alaska  34.0
# 1     2019  2019 Annual  Adverse Childhood Experiences        Alabama  46.0
# 2     2019  2019 Annual  Adverse Childhood Experiences  United States   NaN
# 3     2019  2019 Annual  Adverse Childhood Experiences       Arkansas  47.0
# 4     2019  2019 Annual  Adverse Childhood Experiences        Arizona  48.0
#
#    Value  Score  Lower CI  Upper CI  \
# 0   24.1   0.96      27.7      20.5
# 1   26.3   1.56      30.1      22.5
# 2   20.5    NaN      21.2      19.8
# 3   27.1   1.76      30.8      23.3
# 4   27.3   1.82      31.1      23.4
#
#                                               Source Source Year
# 0  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# 1  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# 2  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# ...

# %%
df2019.count()
# Out:
# Edition         32642
# Report Type     32642
# Measure Name    32642
# State Name      32642
# Rank            18950
# Value           27576
# Score           16803
# Lower CI        26006
# Upper CI        26006
# Source          32642
# Source Year     32486
# dtype: int64

# %%
df2019['Measure Name'].unique()
# Out:
# array(['Adverse Childhood Experiences', 'Air Pollution',
#        'All Determinants', 'All Outcomes', 'Behaviors',
#        'Below poverty threshold', 'Cancer Deaths',
#        'Cancer Deaths - American Indian/Alaska Native',
#        'Cancer Deaths - Asian/Pacific Islander',
#        'Cancer Deaths - Black/African American',
#        'Cancer Deaths - Crude Rate', 'Cancer Deaths - Female',
#        'Cancer Deaths - Hispanic/Latino', 'Cancer Deaths - Male',
#        'Cancer Deaths - Standard Age Adjustment', 'Cancer Deaths - White',
#        'Cardiovascular Deaths',
#        'Cardiovascular Deaths - American Indian/Alaska Native',
#        'Cardiovascular Deaths - Asian/Pacific Islander',
#        'Cardiovascular Deaths - Black/African American',
#        'Cardiovascular Deaths - Crude Rate',
#        'Cardiovascular Deaths - Female',
#        'Cardiovascular Deaths - Hispanic/Latino',
#        'Cardiovascular Deaths - Male',
# ...

# %%
#'Below poverty threshold','Cancer Deaths','Cardiovascular Deaths','Cholesterol Check','Diabetes','Drug Deaths',

# %%
Disparity=df2019[df2019['Measure Name']=='Disparity in Health Status']

# %%
Disparity.head()
# Out:
#       Edition  Report Type                Measure Name  State Name  Rank  \
# 7790     2019  2019 Annual  Disparity in Health Status     Alabama  33.0
# 7791     2019  2019 Annual  Disparity in Health Status      Alaska  16.0
# 7792     2019  2019 Annual  Disparity in Health Status     Arizona  31.0
# 7793     2019  2019 Annual  Disparity in Health Status    Arkansas  10.0
# 7794     2019  2019 Annual  Disparity in Health Status  California  47.0
#
#       Value  Score  Lower CI  Upper CI  \
# 7790   28.0   0.08       NaN       NaN
# 7791   23.5  -0.84       NaN       NaN
# 7792   27.1  -0.10       NaN       NaN
# 7793   21.6  -1.23       NaN       NaN
# 7794   31.8   0.86       NaN       NaN
#
#                                                Source Source Year
# 7790  CDC, Behavioral Risk Factor Surveillance System        2018
# 7791  CDC, Behavioral Risk Factor Surveillance System        2018
# 7792  CDC, Behavioral Risk Factor Surveillance System        2018
# ...

# %%
Disparity.isnull().any()
# Out:
# Edition         False
# Report Type     False
# Measure Name    False
# State Name      False
# Rank             True
# Value           False
# Score            True
# Lower CI         True
# Upper CI         True
# Source          False
# Source Year     False
# dtype: bool

# %%
Disparity.loc[Disparity.isnull().any(axis=1)]
# Out:
#       Edition  Report Type                Measure Name            State Name  \
# 7790     2019  2019 Annual  Disparity in Health Status               Alabama
# 7791     2019  2019 Annual  Disparity in Health Status                Alaska
# 7792     2019  2019 Annual  Disparity in Health Status               Arizona
# 7793     2019  2019 Annual  Disparity in Health Status              Arkansas
# 7794     2019  2019 Annual  Disparity in Health Status            California
# 7795     2019  2019 Annual  Disparity in Health Status              Colorado
# 7796     2019  2019 Annual  Disparity in Health Status           Connecticut
# 7797     2019  2019 Annual  Disparity in Health Status              Delaware
# 7798     2019  2019 Annual  Disparity in Health Status               Florida
# 7799     2019  2019 Annual  Disparity in Health Status               Georgia
# 7800     2019  2019 Annual  Disparity in Health Status                Hawaii
# ...

# %%
Disparity = Disparity.fillna(value=0)
Disparity
# Out:
#       Edition  Report Type                Measure Name            State Name  \
# 7790     2019  2019 Annual  Disparity in Health Status               Alabama
# 7791     2019  2019 Annual  Disparity in Health Status                Alaska
# 7792     2019  2019 Annual  Disparity in Health Status               Arizona
# 7793     2019  2019 Annual  Disparity in Health Status              Arkansas
# 7794     2019  2019 Annual  Disparity in Health Status            California
# 7795     2019  2019 Annual  Disparity in Health Status              Colorado
# 7796     2019  2019 Annual  Disparity in Health Status           Connecticut
# 7797     2019  2019 Annual  Disparity in Health Status              Delaware
# 7798     2019  2019 Annual  Disparity in Health Status               Florida
# 7799     2019  2019 Annual  Disparity in Health Status               Georgia
# 7800     2019  2019 Annual  Disparity in Health Status                Hawaii
# ...

# %%
Disparity.count()
# Out:
# Edition         52
# Report Type     52
# Measure Name    52
# State Name      52
# Rank            52
# Value           52
# Score           52
# Lower CI        52
# Upper CI        52
# Source          52
# Source Year     52
# dtype: int64

# %%
list(Disparity.columns.values)
# Out:
# ['Edition',
#  'Report Type',
#  'Measure Name',
#  'State Name',
#  'Rank',
#  'Value',
#  'Score',
#  'Lower CI',
#  'Upper CI',
#  'Source',
#  'Source Year']

# %%
Disparity = Disparity[["State Name",
                                "Edition", 
                              "Measure Name",
                              "Rank",
                              "Value"]]

# %%
Disparity.head()
# Out:
#       State Name  Edition                Measure Name  Rank  Value
# 7790     Alabama     2019  Disparity in Health Status  33.0   28.0
# 7791      Alaska     2019  Disparity in Health Status  16.0   23.5
# 7792     Arizona     2019  Disparity in Health Status  31.0   27.1
# 7793    Arkansas     2019  Disparity in Health Status  10.0   21.6
# 7794  California     2019  Disparity in Health Status  47.0   31.8

# %%
Disparity.rename(columns = {'Rank' : 'Disparity_in_Health_Status_Rank', 
                             'Value' : 'Disparity_in_Health_Status_Value',
                           'State Name': 'State',
                           'Edition': 'Year'}, 
                  inplace = True)
# Out:
# C:\Users\steph\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
Disparity.head()
# Out:
#            State  Year                Measure Name  \
# 7790     Alabama  2019  Disparity in Health Status
# 7791      Alaska  2019  Disparity in Health Status
# 7792     Arizona  2019  Disparity in Health Status
# 7793    Arkansas  2019  Disparity in Health Status
# 7794  California  2019  Disparity in Health Status
#
#       Disparity_in_Health_Status_Rank  Disparity_in_Health_Status_Value
# 7790                             33.0                              28.0
# 7791                             16.0                              23.5
# 7792                             31.0                              27.1
# 7793                             10.0                              21.6
# 7794                             47.0                              31.8

# %%
Disparity = Disparity.drop('Measure Name',axis=1)

# %%
Disparity.head()
# Out:
#            State  Year  Disparity_in_Health_Status_Rank  \
# 7790     Alabama  2019                             33.0
# 7791      Alaska  2019                             16.0
# 7792     Arizona  2019                             31.0
# 7793    Arkansas  2019                             10.0
# 7794  California  2019                             47.0
#
#       Disparity_in_Health_Status_Value
# 7790                              28.0
# 7791                              23.5
# 7792                              27.1
# 7793                              21.6
# 7794                              31.8

# %%
Disparity.to_csv(os.path.join("Data","Raw","America_Health_Rankings","2019 MidStep","Disparity_in_Health_Status.csv"),index = False)
