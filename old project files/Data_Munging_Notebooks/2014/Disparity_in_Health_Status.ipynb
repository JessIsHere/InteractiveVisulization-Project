# %%
import pandas as pd
from datetime import datetime
import os
import numpy as np

# %%
file = pd.read_csv(os.path.join("..","..","Data","Raw","America_Health_Rankings","2014-Annual.csv"))
print(file)
# Out:
#        Edition  Report Type   Measure Name            State Name Rank  Value  \
# 0         2014  2014 Annual  Air Pollution               Alabama   36   10.0
# 1         2014  2014 Annual  Air Pollution                Alaska    1    4.9
# 2         2014  2014 Annual  Air Pollution               Arizona   35    9.9
# 3         2014  2014 Annual  Air Pollution              Arkansas   42   10.3
# 4         2014  2014 Annual  Air Pollution            California   50   13.9
# 5         2014  2014 Annual  Air Pollution              Colorado    7    6.8
# 6         2014  2014 Annual  Air Pollution           Connecticut   19    8.7
# 7         2014  2014 Annual  Air Pollution              Delaware   40   10.2
# 8         2014  2014 Annual  Air Pollution               Florida   10    7.4
# 9         2014  2014 Annual  Air Pollution               Georgia   42   10.3
# 10        2014  2014 Annual  Air Pollution                Hawaii   19    8.7
# ...

# %%
df2014 = pd.DataFrame(file)
df2014.head()
# Out:
#    Edition  Report Type   Measure Name  State Name Rank  Value  Score  \
# 0     2014  2014 Annual  Air Pollution     Alabama   36   10.0   0.06
# 1     2014  2014 Annual  Air Pollution      Alaska    1    4.9  -2.00
# 2     2014  2014 Annual  Air Pollution     Arizona   35    9.9   0.00
# 3     2014  2014 Annual  Air Pollution    Arkansas   42   10.3   0.22
# 4     2014  2014 Annual  Air Pollution  California   50   13.9   2.00
#
#    Lower CI  Upper CI                                             Source  \
# 0       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 1       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 2       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 3       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 4       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
#
#   Source Year
# 0   2011-2013
# 1   2011-2013
# 2   2011-2013
# 3   2011-2013
# 4   2011-2013

# %%
df2014.count()
# Out:
# Edition         28506
# Report Type     28495
# Measure Name    28495
# State Name      28495
# Rank            20768
# Value           26043
# Score           20511
# Lower CI        23475
# Upper CI        23475
# Source          28484
# Source Year     27756
# dtype: int64

# %%
df2014['Measure Name'].unique()
# Out:
# array(['Air Pollution', 'All Determinants', 'All Outcomes',
#        'Binge Drinking', 'Binge Drinking - $25-$49,999',
#        'Binge Drinking - $50-$74,999', 'Binge Drinking - $75,000 or More',
#        'Binge Drinking - Ages 18-44', 'Binge Drinking - Ages 45-64',
#        'Binge Drinking - Ages 65+',
#        'Binge Drinking - American Indian/Alaskan Native',
#        'Binge Drinking - Asian', 'Binge Drinking - Black',
#        'Binge Drinking - College Grad', 'Binge Drinking - Female',
#        'Binge Drinking - Hawaiian/Pacific Islander',
#        'Binge Drinking - High School Grad', 'Binge Drinking - Hispanic',
#        'Binge Drinking - Less Than $25,000',
#        'Binge Drinking - Less Than High School', 'Binge Drinking - Male',
#        'Binge Drinking - Rural', 'Binge Drinking - Some College',
#        'Binge Drinking - Suburban', 'Binge Drinking - Urban',
#        'Binge Drinking - White', 'Cancer Deaths',
#        'Cancer Deaths - American Indian/Alaska Native',
# ...

# %%
#'Below poverty threshold','Cancer Deaths','Cardiovascular Deaths','Cholesterol Check','Diabetes','Drug Deaths',

# %%
Disparity=df2014[df2014['Measure Name']=='Disparity in Health Status']

# %%
Disparity.head()
# Out:
#       Edition  Report Type                Measure Name  State Name Rank  \
# 8840     2014  2014 Annual  Disparity in Health Status     Alabama    3
# 8841     2014  2014 Annual  Disparity in Health Status      Alaska   13
# 8842     2014  2014 Annual  Disparity in Health Status     Arizona   48
# 8843     2014  2014 Annual  Disparity in Health Status    Arkansas    9
# 8844     2014  2014 Annual  Disparity in Health Status  California   50
#
#       Value  Score  Lower CI  Upper CI  \
# 8840   19.4  -2.00       NaN       NaN
# 8841   25.7  -1.12       NaN       NaN
# 8842   36.6   1.02       NaN       NaN
# 8843   24.2  -1.41       NaN       NaN
# 8844   38.6   1.41       NaN       NaN
#
#                                                Source Source Year
# 8840  CDC, Behavioral Risk Factor Surveillance System        2013
# 8841  CDC, Behavioral Risk Factor Surveillance System        2013
# 8842  CDC, Behavioral Risk Factor Surveillance System        2013
# ...

# %%
Disparity.isnull().any()
# Out:
# Edition         False
# Report Type     False
# Measure Name    False
# State Name      False
# Rank             True
# Value           False
# Score            True
# Lower CI         True
# Upper CI         True
# Source          False
# Source Year     False
# dtype: bool

# %%
Disparity.loc[Disparity.isnull().any(axis=1)]
# Out:
#       Edition  Report Type                Measure Name            State Name  \
# 8840     2014  2014 Annual  Disparity in Health Status               Alabama
# 8841     2014  2014 Annual  Disparity in Health Status                Alaska
# 8842     2014  2014 Annual  Disparity in Health Status               Arizona
# 8843     2014  2014 Annual  Disparity in Health Status              Arkansas
# 8844     2014  2014 Annual  Disparity in Health Status            California
# 8845     2014  2014 Annual  Disparity in Health Status              Colorado
# 8846     2014  2014 Annual  Disparity in Health Status           Connecticut
# 8847     2014  2014 Annual  Disparity in Health Status              Delaware
# 8848     2014  2014 Annual  Disparity in Health Status               Florida
# 8849     2014  2014 Annual  Disparity in Health Status               Georgia
# 8850     2014  2014 Annual  Disparity in Health Status                Hawaii
# ...

# %%
Disparity = Disparity.fillna(value=0)
Disparity
# Out:
#       Edition  Report Type                Measure Name            State Name  \
# 8840     2014  2014 Annual  Disparity in Health Status               Alabama
# 8841     2014  2014 Annual  Disparity in Health Status                Alaska
# 8842     2014  2014 Annual  Disparity in Health Status               Arizona
# 8843     2014  2014 Annual  Disparity in Health Status              Arkansas
# 8844     2014  2014 Annual  Disparity in Health Status            California
# 8845     2014  2014 Annual  Disparity in Health Status              Colorado
# 8846     2014  2014 Annual  Disparity in Health Status           Connecticut
# 8847     2014  2014 Annual  Disparity in Health Status              Delaware
# 8848     2014  2014 Annual  Disparity in Health Status               Florida
# 8849     2014  2014 Annual  Disparity in Health Status               Georgia
# 8850     2014  2014 Annual  Disparity in Health Status                Hawaii
# ...

# %%
Disparity.count()
# Out:
# Edition         52
# Report Type     52
# Measure Name    52
# State Name      52
# Rank            52
# Value           52
# Score           52
# Lower CI        52
# Upper CI        52
# Source          52
# Source Year     52
# dtype: int64

# %%
list(Disparity.columns.values)
# Out:
# ['Edition',
#  'Report Type',
#  'Measure Name',
#  'State Name',
#  'Rank',
#  'Value',
#  'Score',
#  'Lower CI',
#  'Upper CI',
#  'Source',
#  'Source Year']

# %%
Disparity = Disparity[["State Name",
                                "Edition", 
                              "Measure Name",
                              "Rank",
                              "Value"]]

# %%
Disparity.head()
# Out:
#       State Name  Edition                Measure Name Rank  Value
# 8840     Alabama     2014  Disparity in Health Status    3   19.4
# 8841      Alaska     2014  Disparity in Health Status   13   25.7
# 8842     Arizona     2014  Disparity in Health Status   48   36.6
# 8843    Arkansas     2014  Disparity in Health Status    9   24.2
# 8844  California     2014  Disparity in Health Status   50   38.6

# %%
Disparity.rename(columns = {'Rank' : 'Disparity_in_Health_Status_Rank', 
                             'Value' : 'Disparity_in_Health_Status_Value',
                           'State Name': 'State',
                           'Edition': 'Year'}, 
                  inplace = True)
# Out:
# C:\Users\steph\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
Disparity.head()
# Out:
#            State  Year                Measure Name  \
# 8840     Alabama  2014  Disparity in Health Status
# 8841      Alaska  2014  Disparity in Health Status
# 8842     Arizona  2014  Disparity in Health Status
# 8843    Arkansas  2014  Disparity in Health Status
# 8844  California  2014  Disparity in Health Status
#
#      Disparity_in_Health_Status_Rank  Disparity_in_Health_Status_Value
# 8840                               3                              19.4
# 8841                              13                              25.7
# 8842                              48                              36.6
# 8843                               9                              24.2
# 8844                              50                              38.6

# %%
Disparity = Disparity.drop('Measure Name',axis=1)

# %%
Disparity.head()
# Out:
#            State  Year Disparity_in_Health_Status_Rank  \
# 8840     Alabama  2014                               3
# 8841      Alaska  2014                              13
# 8842     Arizona  2014                              48
# 8843    Arkansas  2014                               9
# 8844  California  2014                              50
#
#       Disparity_in_Health_Status_Value
# 8840                              19.4
# 8841                              25.7
# 8842                              36.6
# 8843                              24.2
# 8844                              38.6

# %%
Disparity.to_csv(os.path.join("..","..","Data","Raw","America_Health_Rankings","2014 MidStep","Disparity_in_Health_Status.csv"),index = False)
