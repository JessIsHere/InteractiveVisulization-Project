# %%
import pandas as pd
from datetime import datetime
import os
import numpy as np

# %%
file = pd.read_csv(os.path.join("..","..","Data","Raw","America_Health_Rankings","2014-Annual.csv"))
print(file)
# Out:
#        Edition  Report Type   Measure Name            State Name Rank  Value  \
# 0         2014  2014 Annual  Air Pollution               Alabama   36   10.0
# 1         2014  2014 Annual  Air Pollution                Alaska    1    4.9
# 2         2014  2014 Annual  Air Pollution               Arizona   35    9.9
# 3         2014  2014 Annual  Air Pollution              Arkansas   42   10.3
# 4         2014  2014 Annual  Air Pollution            California   50   13.9
# 5         2014  2014 Annual  Air Pollution              Colorado    7    6.8
# 6         2014  2014 Annual  Air Pollution           Connecticut   19    8.7
# 7         2014  2014 Annual  Air Pollution              Delaware   40   10.2
# 8         2014  2014 Annual  Air Pollution               Florida   10    7.4
# 9         2014  2014 Annual  Air Pollution               Georgia   42   10.3
# 10        2014  2014 Annual  Air Pollution                Hawaii   19    8.7
# ...

# %%
df2014 = pd.DataFrame(file)
df2014.head()
# Out:
#    Edition  Report Type   Measure Name  State Name Rank  Value  Score  \
# 0     2014  2014 Annual  Air Pollution     Alabama   36   10.0   0.06
# 1     2014  2014 Annual  Air Pollution      Alaska    1    4.9  -2.00
# 2     2014  2014 Annual  Air Pollution     Arizona   35    9.9   0.00
# 3     2014  2014 Annual  Air Pollution    Arkansas   42   10.3   0.22
# 4     2014  2014 Annual  Air Pollution  California   50   13.9   2.00
#
#    Lower CI  Upper CI                                             Source  \
# 0       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 1       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 2       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 3       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 4       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
#
#   Source Year
# 0   2011-2013
# 1   2011-2013
# 2   2011-2013
# 3   2011-2013
# 4   2011-2013

# %%
df2014.count()
# Out:
# Edition         28506
# Report Type     28495
# Measure Name    28495
# State Name      28495
# Rank            20768
# Value           26043
# Score           20511
# Lower CI        23475
# Upper CI        23475
# Source          28484
# Source Year     27756
# dtype: int64

# %%
df2014['Measure Name'].unique()
# Out:
# array(['Air Pollution', 'All Determinants', 'All Outcomes',
#        'Binge Drinking', 'Binge Drinking - $25-$49,999',
#        'Binge Drinking - $50-$74,999', 'Binge Drinking - $75,000 or More',
#        'Binge Drinking - Ages 18-44', 'Binge Drinking - Ages 45-64',
#        'Binge Drinking - Ages 65+',
#        'Binge Drinking - American Indian/Alaskan Native',
#        'Binge Drinking - Asian', 'Binge Drinking - Black',
#        'Binge Drinking - College Grad', 'Binge Drinking - Female',
#        'Binge Drinking - Hawaiian/Pacific Islander',
#        'Binge Drinking - High School Grad', 'Binge Drinking - Hispanic',
#        'Binge Drinking - Less Than $25,000',
#        'Binge Drinking - Less Than High School', 'Binge Drinking - Male',
#        'Binge Drinking - Rural', 'Binge Drinking - Some College',
#        'Binge Drinking - Suburban', 'Binge Drinking - Urban',
#        'Binge Drinking - White', 'Cancer Deaths',
#        'Cancer Deaths - American Indian/Alaska Native',
# ...

# %%
#'Below poverty threshold','Cancer Deaths','Cardiovascular Deaths','Cholesterol Check','Diabetes','Drug Deaths',

# %%
Infant_Mortality=df2014[df2014['Measure Name']=='Infant Mortality']

# %%
Infant_Mortality.head()
# Out:
#        Edition  Report Type      Measure Name  State Name Rank  Value  Score  \
# 18939     2014  2014 Annual  Infant Mortality     Alabama   49    8.6   2.00
# 18940     2014  2014 Annual  Infant Mortality      Alaska    2    4.5  -1.27
# 18941     2014  2014 Annual  Infant Mortality     Arizona   20    5.9  -0.08
# 18942     2014  2014 Annual  Infant Mortality    Arkansas   39    7.2   1.01
# 18943     2014  2014 Annual  Infant Mortality  California    4    4.6  -1.18
#
#        Lower CI  Upper CI    Source Source Year
# 18939       NaN       NaN  AHR data         NaN
# 18940       NaN       NaN  AHR data         NaN
# 18941       NaN       NaN  AHR data         NaN
# 18942       NaN       NaN  AHR data         NaN
# 18943       NaN       NaN  AHR data         NaN

# %%
Infant_Mortality.isnull().any()
# Out:
# Edition         False
# Report Type     False
# Measure Name    False
# State Name      False
# Rank             True
# Value           False
# Score            True
# Lower CI         True
# Upper CI         True
# Source          False
# Source Year      True
# dtype: bool

# %%
Infant_Mortality.loc[Infant_Mortality.isnull().any(axis=1)]
# Out:
#        Edition  Report Type      Measure Name            State Name Rank  \
# 18939     2014  2014 Annual  Infant Mortality               Alabama   49
# 18940     2014  2014 Annual  Infant Mortality                Alaska    2
# 18941     2014  2014 Annual  Infant Mortality               Arizona   20
# 18942     2014  2014 Annual  Infant Mortality              Arkansas   39
# 18943     2014  2014 Annual  Infant Mortality            California    4
# 18944     2014  2014 Annual  Infant Mortality              Colorado   12
# 18945     2014  2014 Annual  Infant Mortality           Connecticut   12
# 18946     2014  2014 Annual  Infant Mortality              Delaware   47
# 18947     2014  2014 Annual  Infant Mortality               Florida   25
# 18948     2014  2014 Annual  Infant Mortality               Georgia   29
# 18949     2014  2014 Annual  Infant Mortality                Hawaii   12
# 18950     2014  2014 Annual  Infant Mortality                 Idaho   16
# ...

# %%
Infant_Mortality = Infant_Mortality.fillna(value=0)
Infant_Mortality
# Out:
#        Edition  Report Type      Measure Name            State Name Rank  \
# 18939     2014  2014 Annual  Infant Mortality               Alabama   49
# 18940     2014  2014 Annual  Infant Mortality                Alaska    2
# 18941     2014  2014 Annual  Infant Mortality               Arizona   20
# 18942     2014  2014 Annual  Infant Mortality              Arkansas   39
# 18943     2014  2014 Annual  Infant Mortality            California    4
# 18944     2014  2014 Annual  Infant Mortality              Colorado   12
# 18945     2014  2014 Annual  Infant Mortality           Connecticut   12
# 18946     2014  2014 Annual  Infant Mortality              Delaware   47
# 18947     2014  2014 Annual  Infant Mortality               Florida   25
# 18948     2014  2014 Annual  Infant Mortality               Georgia   29
# 18949     2014  2014 Annual  Infant Mortality                Hawaii   12
# 18950     2014  2014 Annual  Infant Mortality                 Idaho   16
# ...

# %%
Infant_Mortality.count()
# Out:
# Edition         52
# Report Type     52
# Measure Name    52
# State Name      52
# Rank            52
# Value           52
# Score           52
# Lower CI        52
# Upper CI        52
# Source          52
# Source Year     52
# dtype: int64

# %%
list(Infant_Mortality.columns.values)
# Out:
# ['Edition',
#  'Report Type',
#  'Measure Name',
#  'State Name',
#  'Rank',
#  'Value',
#  'Score',
#  'Lower CI',
#  'Upper CI',
#  'Source',
#  'Source Year']

# %%
Infant_Mortality = Infant_Mortality[["State Name",
            "Edition", 
            "Measure Name",
            "Rank",
            "Value"]]

# %%
Infant_Mortality.head()
# Out:
#        State Name  Edition      Measure Name Rank  Value
# 18939     Alabama     2014  Infant Mortality   49    8.6
# 18940      Alaska     2014  Infant Mortality    2    4.5
# 18941     Arizona     2014  Infant Mortality   20    5.9
# 18942    Arkansas     2014  Infant Mortality   39    7.2
# 18943  California     2014  Infant Mortality    4    4.6

# %%
Infant_Mortality.rename(columns = {'Rank' : 'Infant_Mortality_Rank', 
                             'Value' : 'Infant_Mortality_Value',
                             'State Name': 'State',
                             'Edition': 'Year'}, 
                  inplace = True)
# Out:
# C:\Users\steph\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
Infant_Mortality.head()
# Out:
#             State  Year      Measure Name Infant_Mortality_Rank  \
# 18939     Alabama  2014  Infant Mortality                    49
# 18940      Alaska  2014  Infant Mortality                     2
# 18941     Arizona  2014  Infant Mortality                    20
# 18942    Arkansas  2014  Infant Mortality                    39
# 18943  California  2014  Infant Mortality                     4
#
#        Infant_Mortality_Value
# 18939                     8.6
# 18940                     4.5
# 18941                     5.9
# 18942                     7.2
# 18943                     4.6

# %%
Infant_Mortality = Infant_Mortality.drop('Measure Name',axis=1)

# %%
Infant_Mortality.head()
# Out:
#             State  Year Infant_Mortality_Rank  Infant_Mortality_Value
# 18939     Alabama  2014                    49                     8.6
# 18940      Alaska  2014                     2                     4.5
# 18941     Arizona  2014                    20                     5.9
# 18942    Arkansas  2014                    39                     7.2
# 18943  California  2014                     4                     4.6

# %%
Infant_Mortality.to_csv(os.path.join("..","..","Data","Raw","America_Health_Rankings","2014 MidStep","Infant_Mortality.csv"),index = False)
