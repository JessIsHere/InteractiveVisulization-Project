# %%
import pandas as pd
from datetime import datetime
import os
import numpy as np

# %%
file = pd.read_csv(os.path.join("..","..","Data","Raw","America_Health_Rankings","2017-Annual.csv"))
print(file)
# Out:
#        Edition  Report Type        Measure Name      State Name  Rank  Value  \
# 0         2017  2017 Annual       Air Pollution          Alaska  36.0    8.7
# 1         2017  2017 Annual       Air Pollution         Alabama  39.0    8.9
# 2         2017  2017 Annual       Air Pollution        Arkansas  16.0    7.2
# 3         2017  2017 Annual       Air Pollution         Arizona  46.0    9.7
# 4         2017  2017 Annual       Air Pollution      California  50.0   11.7
# 5         2017  2017 Annual       Air Pollution        Colorado  12.0    6.6
# 6         2017  2017 Annual       Air Pollution     Connecticut  35.0    8.6
# 7         2017  2017 Annual       Air Pollution        Delaware  43.0    9.1
# 8         2017  2017 Annual       Air Pollution         Florida  13.0    6.8
# 9         2017  2017 Annual       Air Pollution         Georgia  41.0    9.0
# 10        2017  2017 Annual       Air Pollution          Hawaii   6.0    5.9
# ...

# %%
df2017 = pd.DataFrame(file)
df2017.head()
# Out:
#    Edition  Report Type   Measure Name  State Name  Rank  Value  Score  \
# 0     2017  2017 Annual  Air Pollution      Alaska  36.0    8.7   0.06
# 1     2017  2017 Annual  Air Pollution     Alabama  39.0    8.9   0.19
# 2     2017  2017 Annual  Air Pollution    Arkansas  16.0    7.2  -0.90
# 3     2017  2017 Annual  Air Pollution     Arizona  46.0    9.7   0.71
# 4     2017  2017 Annual  Air Pollution  California  50.0   11.7   2.00
#
#    Lower CI  Upper CI                                             Source  \
# 0       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 1       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 2       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 3       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 4       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
#
#   Source Year
# 0   2014-2016
# 1   2014-2016
# 2   2014-2016
# 3   2014-2016
# 4   2014-2016

# %%
df2017.count()
# Out:
# Edition         37738
# Report Type     37738
# Measure Name    37738
# State Name      37738
# Rank            31308
# Value           32122
# Score           31156
# Lower CI        34409
# Upper CI        34409
# Source          37738
# Source Year     37322
# dtype: int64

# %%
df2017['Measure Name'].unique()
# Out:
# array(['Air Pollution', 'All Determinants', 'All Outcomes', 'Behaviors',
#        'Binge Drinking', 'Binge Drinking - $25-$49,999',
#        'Binge Drinking - $50-$74,999', 'Binge Drinking - $75,000 or More',
#        'Binge Drinking - Ages 18-44', 'Binge Drinking - Ages 45-64',
#        'Binge Drinking - Ages 65+',
#        'Binge Drinking - American Indian/Alaskan Native',
#        'Binge Drinking - Asian', 'Binge Drinking - Black',
#        'Binge Drinking - College Grad', 'Binge Drinking - Female',
#        'Binge Drinking - Hawaiian/Pacific Islander',
#        'Binge Drinking - High School Grad', 'Binge Drinking - Hispanic',
#        'Binge Drinking - Less Than $25,000',
#        'Binge Drinking - Less Than High School', 'Binge Drinking - Male',
#        'Binge Drinking - Multiracial', 'Binge Drinking - Other Race',
#        'Binge Drinking - Rural', 'Binge Drinking - Some College',
#        'Binge Drinking - Suburban', 'Binge Drinking - Urban',
# ...

# %%
#'Below poverty threshold','Cancer Deaths','Cardiovascular Deaths','Cholesterol Check','Diabetes','Drug Deaths',

# %%
Drug_Deaths=df2017[df2017['Measure Name']=='Drug Deaths']

# %%
Drug_Deaths.head()
# Out:
#        Edition  Report Type Measure Name  State Name  Rank  Value  Score  \
# 10962     2017  2017 Annual  Drug Deaths     Alabama  22.0   14.3  -0.64
# 10963     2017  2017 Annual  Drug Deaths      Alaska  27.0   15.6  -0.41
# 10964     2017  2017 Annual  Drug Deaths     Arizona  37.0   19.0   0.20
# 10965     2017  2017 Annual  Drug Deaths    Arkansas  14.0   12.3  -1.00
# 10966     2017  2017 Annual  Drug Deaths  California  10.0   11.8  -1.08
#
#        Lower CI  Upper CI                                             Source  \
# 10962      14.9      13.7  CDC WONDER Online Database, Underlying Cause o...
# 10963      17.3      14.0  CDC WONDER Online Database, Underlying Cause o...
# 10964      19.6      18.4  CDC WONDER Online Database, Underlying Cause o...
# 10965      13.0      11.6  CDC WONDER Online Database, Underlying Cause o...
# 10966      12.0      11.6  CDC WONDER Online Database, Underlying Cause o...
#
#       Source Year
# 10962   2013-2015
# 10963   2013-2015
# ...

# %%
Drug_Deaths.isnull().any()
# Out:
# Edition         False
# Report Type     False
# Measure Name    False
# State Name      False
# Rank             True
# Value           False
# Score            True
# Lower CI        False
# Upper CI        False
# Source          False
# Source Year     False
# dtype: bool

# %%
Drug_Deaths.loc[Drug_Deaths.isnull().any(axis=1)]
# Out:
#        Edition  Report Type Measure Name            State Name  Rank  Value  \
# 11012     2017  2017 Annual  Drug Deaths         United States   NaN   15.0
# 11013     2017  2017 Annual  Drug Deaths  District of Columbia   NaN   17.9
#
#        Score  Lower CI  Upper CI  \
# 11012    NaN      15.1      14.9
# 11013    NaN      19.9      16.0
#
#                                                   Source Source Year
# 11012  CDC WONDER Online Database, Underlying Cause o...   2013-2015
# 11013  CDC WONDER Online Database, Underlying Cause o...   2013-2015

# %%
Drug_Deaths = Drug_Deaths.fillna(value=0)
Drug_Deaths
# Out:
#        Edition  Report Type Measure Name            State Name  Rank  Value  \
# 10962     2017  2017 Annual  Drug Deaths               Alabama  22.0   14.3
# 10963     2017  2017 Annual  Drug Deaths                Alaska  27.0   15.6
# 10964     2017  2017 Annual  Drug Deaths               Arizona  37.0   19.0
# 10965     2017  2017 Annual  Drug Deaths              Arkansas  14.0   12.3
# 10966     2017  2017 Annual  Drug Deaths            California  10.0   11.8
# 10967     2017  2017 Annual  Drug Deaths              Colorado  28.0   16.0
# 10968     2017  2017 Annual  Drug Deaths           Connecticut  36.0   18.4
# 10969     2017  2017 Annual  Drug Deaths              Delaware  40.0   20.0
# 10970     2017  2017 Annual  Drug Deaths               Florida  20.0   14.1
# 10971     2017  2017 Annual  Drug Deaths               Georgia  12.0   11.9
# 10972     2017  2017 Annual  Drug Deaths                Hawaii   8.0   11.5
# ...

# %%
Drug_Deaths.count()
# Out:
# Edition         52
# Report Type     52
# Measure Name    52
# State Name      52
# Rank            52
# Value           52
# Score           52
# Lower CI        52
# Upper CI        52
# Source          52
# Source Year     52
# dtype: int64

# %%
list(Drug_Deaths.columns.values)
# Out:
# ['Edition',
#  'Report Type',
#  'Measure Name',
#  'State Name',
#  'Rank',
#  'Value',
#  'Score',
#  'Lower CI',
#  'Upper CI',
#  'Source',
#  'Source Year']

# %%
Drug_Deaths = Drug_Deaths[["State Name",
                                "Edition", 
                              "Measure Name",
                              "Rank",
                              "Value"]]

# %%
Drug_Deaths.head()
# Out:
#        State Name  Edition Measure Name  Rank  Value
# 10962     Alabama     2017  Drug Deaths  22.0   14.3
# 10963      Alaska     2017  Drug Deaths  27.0   15.6
# 10964     Arizona     2017  Drug Deaths  37.0   19.0
# 10965    Arkansas     2017  Drug Deaths  14.0   12.3
# 10966  California     2017  Drug Deaths  10.0   11.8

# %%
Drug_Deaths.rename(columns = {'Rank' : 'Drug_Deaths_Rank', 
                             'Value' : 'Drug_Deaths_Value',
                             'State Name': 'State',
                             'Edition': 'Year'}, 
                  inplace = True)
# Out:
# C:\Users\steph\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
Drug_Deaths.head()
# Out:
#             State  Year Measure Name  Drug_Deaths_Rank  Drug_Deaths_Value
# 10962     Alabama  2017  Drug Deaths              22.0               14.3
# 10963      Alaska  2017  Drug Deaths              27.0               15.6
# 10964     Arizona  2017  Drug Deaths              37.0               19.0
# 10965    Arkansas  2017  Drug Deaths              14.0               12.3
# 10966  California  2017  Drug Deaths              10.0               11.8

# %%
Drug_Deaths = Drug_Deaths.drop('Measure Name',axis=1)

# %%
Drug_Deaths.head()
# Out:
#             State  Year  Drug_Deaths_Rank  Drug_Deaths_Value
# 10962     Alabama  2017              22.0               14.3
# 10963      Alaska  2017              27.0               15.6
# 10964     Arizona  2017              37.0               19.0
# 10965    Arkansas  2017              14.0               12.3
# 10966  California  2017              10.0               11.8

# %%
Drug_Deaths.to_csv(os.path.join("..","..","Data","Raw","America_Health_Rankings","2017 MidStep","Drug_Deaths.csv"), index = False)
