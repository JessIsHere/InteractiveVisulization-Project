# %%
import pandas as pd
from datetime import datetime
import os
import numpy as np

# %%
file = pd.read_csv(os.path.join("..","..","Data","Raw","America_Health_Rankings","2017-Annual.csv"))
print(file)
# Out:
#        Edition  Report Type        Measure Name      State Name  Rank  Value  \
# 0         2017  2017 Annual       Air Pollution          Alaska  36.0    8.7
# 1         2017  2017 Annual       Air Pollution         Alabama  39.0    8.9
# 2         2017  2017 Annual       Air Pollution        Arkansas  16.0    7.2
# 3         2017  2017 Annual       Air Pollution         Arizona  46.0    9.7
# 4         2017  2017 Annual       Air Pollution      California  50.0   11.7
# 5         2017  2017 Annual       Air Pollution        Colorado  12.0    6.6
# 6         2017  2017 Annual       Air Pollution     Connecticut  35.0    8.6
# 7         2017  2017 Annual       Air Pollution        Delaware  43.0    9.1
# 8         2017  2017 Annual       Air Pollution         Florida  13.0    6.8
# 9         2017  2017 Annual       Air Pollution         Georgia  41.0    9.0
# 10        2017  2017 Annual       Air Pollution          Hawaii   6.0    5.9
# ...

# %%
df2017 = pd.DataFrame(file)
df2017.head()
# Out:
#    Edition  Report Type   Measure Name  State Name  Rank  Value  Score  \
# 0     2017  2017 Annual  Air Pollution      Alaska  36.0    8.7   0.06
# 1     2017  2017 Annual  Air Pollution     Alabama  39.0    8.9   0.19
# 2     2017  2017 Annual  Air Pollution    Arkansas  16.0    7.2  -0.90
# 3     2017  2017 Annual  Air Pollution     Arizona  46.0    9.7   0.71
# 4     2017  2017 Annual  Air Pollution  California  50.0   11.7   2.00
#
#    Lower CI  Upper CI                                             Source  \
# 0       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 1       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 2       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 3       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 4       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
#
#   Source Year
# 0   2014-2016
# 1   2014-2016
# 2   2014-2016
# 3   2014-2016
# 4   2014-2016

# %%
df2017.count()
# Out:
# Edition         37738
# Report Type     37738
# Measure Name    37738
# State Name      37738
# Rank            31308
# Value           32122
# Score           31156
# Lower CI        34409
# Upper CI        34409
# Source          37738
# Source Year     37322
# dtype: int64

# %%
df2017['Measure Name'].unique()
# Out:
# array(['Air Pollution', 'All Determinants', 'All Outcomes', 'Behaviors',
#        'Binge Drinking', 'Binge Drinking - $25-$49,999',
#        'Binge Drinking - $50-$74,999', 'Binge Drinking - $75,000 or More',
#        'Binge Drinking - Ages 18-44', 'Binge Drinking - Ages 45-64',
#        'Binge Drinking - Ages 65+',
#        'Binge Drinking - American Indian/Alaskan Native',
#        'Binge Drinking - Asian', 'Binge Drinking - Black',
#        'Binge Drinking - College Grad', 'Binge Drinking - Female',
#        'Binge Drinking - Hawaiian/Pacific Islander',
#        'Binge Drinking - High School Grad', 'Binge Drinking - Hispanic',
#        'Binge Drinking - Less Than $25,000',
#        'Binge Drinking - Less Than High School', 'Binge Drinking - Male',
#        'Binge Drinking - Multiracial', 'Binge Drinking - Other Race',
#        'Binge Drinking - Rural', 'Binge Drinking - Some College',
#        'Binge Drinking - Suburban', 'Binge Drinking - Urban',
# ...

# %%
#'Below poverty threshold','Cancer Deaths','Cardiovascular Deaths','Cholesterol Check','Diabetes','Drug Deaths',

# %%
Unemployment_Rate=df2017[df2017['Measure Name']=='Unemployment Rate, Annual']

# %%
Unemployment_Rate.head()
# Out:
#        Edition  Report Type               Measure Name     State Name  Rank  \
# 36854     2017  2017 Annual  Unemployment Rate, Annual         Alaska  49.0
# 36855     2017  2017 Annual  Unemployment Rate, Annual        Alabama  46.0
# 36856     2017  2017 Annual  Unemployment Rate, Annual  United States   NaN
# 36857     2017  2017 Annual  Unemployment Rate, Annual       Arkansas  10.0
# 36858     2017  2017 Annual  Unemployment Rate, Annual        Arizona  35.0
#
#        Value  Score  Lower CI  Upper CI  \
# 36854    6.6  1.735       NaN       NaN
# 36855    6.0  1.122       NaN       NaN
# 36856    4.9    NaN       NaN       NaN
# 36857    3.9 -1.020       NaN       NaN
# 36858    5.2  0.306       NaN       NaN
#
#                                                   Source Source Year
# 36854  U.S. Department of Labor, Bureau of Labor Stat...        2016
# 36855  U.S. Department of Labor, Bureau of Labor Stat...        2016
# ...

# %%
Unemployment_Rate.isnull().any()
# Out:
# Edition         False
# Report Type     False
# Measure Name    False
# State Name      False
# Rank             True
# Value           False
# Score            True
# Lower CI         True
# Upper CI         True
# Source          False
# Source Year     False
# dtype: bool

# %%
Unemployment_Rate.loc[Unemployment_Rate.isnull().any(axis=1)]
# Out:
#        Edition  Report Type               Measure Name            State Name  \
# 36854     2017  2017 Annual  Unemployment Rate, Annual                Alaska
# 36855     2017  2017 Annual  Unemployment Rate, Annual               Alabama
# 36856     2017  2017 Annual  Unemployment Rate, Annual         United States
# 36857     2017  2017 Annual  Unemployment Rate, Annual              Arkansas
# 36858     2017  2017 Annual  Unemployment Rate, Annual               Arizona
# 36859     2017  2017 Annual  Unemployment Rate, Annual            California
# 36860     2017  2017 Annual  Unemployment Rate, Annual              Colorado
# 36861     2017  2017 Annual  Unemployment Rate, Annual           Connecticut
# 36862     2017  2017 Annual  Unemployment Rate, Annual  District of Columbia
# 36863     2017  2017 Annual  Unemployment Rate, Annual              Delaware
# 36864     2017  2017 Annual  Unemployment Rate, Annual               Florida
# ...

# %%
Unemployment_Rate = Unemployment_Rate.fillna(value=0)
Unemployment_Rate
# Out:
#        Edition  Report Type               Measure Name            State Name  \
# 36854     2017  2017 Annual  Unemployment Rate, Annual                Alaska
# 36855     2017  2017 Annual  Unemployment Rate, Annual               Alabama
# 36856     2017  2017 Annual  Unemployment Rate, Annual         United States
# 36857     2017  2017 Annual  Unemployment Rate, Annual              Arkansas
# 36858     2017  2017 Annual  Unemployment Rate, Annual               Arizona
# 36859     2017  2017 Annual  Unemployment Rate, Annual            California
# 36860     2017  2017 Annual  Unemployment Rate, Annual              Colorado
# 36861     2017  2017 Annual  Unemployment Rate, Annual           Connecticut
# 36862     2017  2017 Annual  Unemployment Rate, Annual  District of Columbia
# 36863     2017  2017 Annual  Unemployment Rate, Annual              Delaware
# 36864     2017  2017 Annual  Unemployment Rate, Annual               Florida
# ...

# %%
Unemployment_Rate.count()
# Out:
# Edition         52
# Report Type     52
# Measure Name    52
# State Name      52
# Rank            52
# Value           52
# Score           52
# Lower CI        52
# Upper CI        52
# Source          52
# Source Year     52
# dtype: int64

# %%
list(Unemployment_Rate.columns.values)
# Out:
# ['Edition',
#  'Report Type',
#  'Measure Name',
#  'State Name',
#  'Rank',
#  'Value',
#  'Score',
#  'Lower CI',
#  'Upper CI',
#  'Source',
#  'Source Year']

# %%
Unemployment_Rate= Unemployment_Rate[["State Name",
                                "Edition", 
                              "Measure Name",
                              "Rank",
                              "Value"]]

# %%
Unemployment_Rate.head()
# Out:
#           State Name  Edition               Measure Name  Rank  Value
# 36854         Alaska     2017  Unemployment Rate, Annual  49.0    6.6
# 36855        Alabama     2017  Unemployment Rate, Annual  46.0    6.0
# 36856  United States     2017  Unemployment Rate, Annual   0.0    4.9
# 36857       Arkansas     2017  Unemployment Rate, Annual  10.0    3.9
# 36858        Arizona     2017  Unemployment Rate, Annual  35.0    5.2

# %%
Unemployment_Rate.rename(columns = {'Rank' : 'Unemployment_Rate_Rank', 
                             'Value' : 'Unemployment_Rate_Value',
                            'State Name': 'State',
                            'Edition': 'Year'}, 
                  inplace = True)
# Out:
# C:\Users\steph\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
Unemployment_Rate.head()
# Out:
#                State  Year               Measure Name  Unemployment_Rate_Rank  \
# 36854         Alaska  2017  Unemployment Rate, Annual                    49.0
# 36855        Alabama  2017  Unemployment Rate, Annual                    46.0
# 36856  United States  2017  Unemployment Rate, Annual                     0.0
# 36857       Arkansas  2017  Unemployment Rate, Annual                    10.0
# 36858        Arizona  2017  Unemployment Rate, Annual                    35.0
#
#        Unemployment_Rate_Value
# 36854                      6.6
# 36855                      6.0
# 36856                      4.9
# 36857                      3.9
# 36858                      5.2

# %%
Unemployment_Rate = Unemployment_Rate.drop('Measure Name',axis=1)

# %%
Unemployment_Rate.head()
# Out:
#                State  Year  Unemployment_Rate_Rank  Unemployment_Rate_Value
# 36854         Alaska  2017                    49.0                      6.6
# 36855        Alabama  2017                    46.0                      6.0
# 36856  United States  2017                     0.0                      4.9
# 36857       Arkansas  2017                    10.0                      3.9
# 36858        Arizona  2017                    35.0                      5.2

# %%
Unemployment_Rate.to_csv(os.path.join("..","..","Data","Raw","America_Health_Rankings","2017 MidStep","Unemployment_Rate.csv"),index = False)
