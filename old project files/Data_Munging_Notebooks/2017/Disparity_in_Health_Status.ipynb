# %%
import pandas as pd
from datetime import datetime
import os
import numpy as np

# %%
file = pd.read_csv(os.path.join("..","..","Data","Raw","America_Health_Rankings","2017-Annual.csv"))
print(file)
# Out:
#        Edition  Report Type        Measure Name      State Name  Rank  Value  \
# 0         2017  2017 Annual       Air Pollution          Alaska  36.0    8.7
# 1         2017  2017 Annual       Air Pollution         Alabama  39.0    8.9
# 2         2017  2017 Annual       Air Pollution        Arkansas  16.0    7.2
# 3         2017  2017 Annual       Air Pollution         Arizona  46.0    9.7
# 4         2017  2017 Annual       Air Pollution      California  50.0   11.7
# 5         2017  2017 Annual       Air Pollution        Colorado  12.0    6.6
# 6         2017  2017 Annual       Air Pollution     Connecticut  35.0    8.6
# 7         2017  2017 Annual       Air Pollution        Delaware  43.0    9.1
# 8         2017  2017 Annual       Air Pollution         Florida  13.0    6.8
# 9         2017  2017 Annual       Air Pollution         Georgia  41.0    9.0
# 10        2017  2017 Annual       Air Pollution          Hawaii   6.0    5.9
# ...

# %%
df2017 = pd.DataFrame(file)
df2017.head()
# Out:
#    Edition  Report Type   Measure Name  State Name  Rank  Value  Score  \
# 0     2017  2017 Annual  Air Pollution      Alaska  36.0    8.7   0.06
# 1     2017  2017 Annual  Air Pollution     Alabama  39.0    8.9   0.19
# 2     2017  2017 Annual  Air Pollution    Arkansas  16.0    7.2  -0.90
# 3     2017  2017 Annual  Air Pollution     Arizona  46.0    9.7   0.71
# 4     2017  2017 Annual  Air Pollution  California  50.0   11.7   2.00
#
#    Lower CI  Upper CI                                             Source  \
# 0       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 1       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 2       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 3       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 4       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
#
#   Source Year
# 0   2014-2016
# 1   2014-2016
# 2   2014-2016
# 3   2014-2016
# 4   2014-2016

# %%
df2017.count()
# Out:
# Edition         37738
# Report Type     37738
# Measure Name    37738
# State Name      37738
# Rank            31308
# Value           32122
# Score           31156
# Lower CI        34409
# Upper CI        34409
# Source          37738
# Source Year     37322
# dtype: int64

# %%
df2017['Measure Name'].unique()
# Out:
# array(['Air Pollution', 'All Determinants', 'All Outcomes', 'Behaviors',
#        'Binge Drinking', 'Binge Drinking - $25-$49,999',
#        'Binge Drinking - $50-$74,999', 'Binge Drinking - $75,000 or More',
#        'Binge Drinking - Ages 18-44', 'Binge Drinking - Ages 45-64',
#        'Binge Drinking - Ages 65+',
#        'Binge Drinking - American Indian/Alaskan Native',
#        'Binge Drinking - Asian', 'Binge Drinking - Black',
#        'Binge Drinking - College Grad', 'Binge Drinking - Female',
#        'Binge Drinking - Hawaiian/Pacific Islander',
#        'Binge Drinking - High School Grad', 'Binge Drinking - Hispanic',
#        'Binge Drinking - Less Than $25,000',
#        'Binge Drinking - Less Than High School', 'Binge Drinking - Male',
#        'Binge Drinking - Multiracial', 'Binge Drinking - Other Race',
#        'Binge Drinking - Rural', 'Binge Drinking - Some College',
#        'Binge Drinking - Suburban', 'Binge Drinking - Urban',
# ...

# %%
#'Below poverty threshold','Cancer Deaths','Cardiovascular Deaths','Cholesterol Check','Diabetes','Drug Deaths',

# %%
Disparity=df2017[df2017['Measure Name']=='Disparity in Health Status']

# %%
Disparity.head()
# Out:
#        Edition  Report Type                Measure Name  State Name  Rank  \
# 10910     2017  2017 Annual  Disparity in Health Status     Alabama  11.0
# 10911     2017  2017 Annual  Disparity in Health Status      Alaska   1.0
# 10912     2017  2017 Annual  Disparity in Health Status     Arizona  21.0
# 10913     2017  2017 Annual  Disparity in Health Status    Arkansas  14.0
# 10914     2017  2017 Annual  Disparity in Health Status  California  49.0
#
#        Value  Score  Lower CI  Upper CI  \
# 10910   25.1  -1.05       NaN       NaN
# 10911   11.1  -2.00       NaN       NaN
# 10912   28.0  -0.49       NaN       NaN
# 10913   25.5  -0.97       NaN       NaN
# 10914   36.3   1.08       NaN       NaN
#
#                                                 Source Source Year
# 10910  CDC, Behavioral Risk Factor Surveillance System        2016
# 10911  CDC, Behavioral Risk Factor Surveillance System        2016
# 10912  CDC, Behavioral Risk Factor Surveillance System        2016
# ...

# %%
Disparity.isnull().any()
# Out:
# Edition         False
# Report Type     False
# Measure Name    False
# State Name      False
# Rank             True
# Value           False
# Score            True
# Lower CI         True
# Upper CI         True
# Source          False
# Source Year     False
# dtype: bool

# %%
Disparity.loc[Disparity.isnull().any(axis=1)]
# Out:
#        Edition  Report Type                Measure Name            State Name  \
# 10910     2017  2017 Annual  Disparity in Health Status               Alabama
# 10911     2017  2017 Annual  Disparity in Health Status                Alaska
# 10912     2017  2017 Annual  Disparity in Health Status               Arizona
# 10913     2017  2017 Annual  Disparity in Health Status              Arkansas
# 10914     2017  2017 Annual  Disparity in Health Status            California
# 10915     2017  2017 Annual  Disparity in Health Status              Colorado
# 10916     2017  2017 Annual  Disparity in Health Status           Connecticut
# 10917     2017  2017 Annual  Disparity in Health Status              Delaware
# 10918     2017  2017 Annual  Disparity in Health Status               Florida
# 10919     2017  2017 Annual  Disparity in Health Status               Georgia
# 10920     2017  2017 Annual  Disparity in Health Status                Hawaii
# ...

# %%
Disparity = Disparity.fillna(value=0)
Disparity
# Out:
#        Edition  Report Type                Measure Name            State Name  \
# 10910     2017  2017 Annual  Disparity in Health Status               Alabama
# 10911     2017  2017 Annual  Disparity in Health Status                Alaska
# 10912     2017  2017 Annual  Disparity in Health Status               Arizona
# 10913     2017  2017 Annual  Disparity in Health Status              Arkansas
# 10914     2017  2017 Annual  Disparity in Health Status            California
# 10915     2017  2017 Annual  Disparity in Health Status              Colorado
# 10916     2017  2017 Annual  Disparity in Health Status           Connecticut
# 10917     2017  2017 Annual  Disparity in Health Status              Delaware
# 10918     2017  2017 Annual  Disparity in Health Status               Florida
# 10919     2017  2017 Annual  Disparity in Health Status               Georgia
# 10920     2017  2017 Annual  Disparity in Health Status                Hawaii
# ...

# %%
Disparity.count()
# Out:
# Edition         52
# Report Type     52
# Measure Name    52
# State Name      52
# Rank            52
# Value           52
# Score           52
# Lower CI        52
# Upper CI        52
# Source          52
# Source Year     52
# dtype: int64

# %%
list(Disparity.columns.values)
# Out:
# ['Edition',
#  'Report Type',
#  'Measure Name',
#  'State Name',
#  'Rank',
#  'Value',
#  'Score',
#  'Lower CI',
#  'Upper CI',
#  'Source',
#  'Source Year']

# %%
Disparity = Disparity[["State Name",
                                "Edition", 
                              "Measure Name",
                              "Rank",
                              "Value"]]

# %%
Disparity.head()
# Out:
#        State Name  Edition                Measure Name  Rank  Value
# 10910     Alabama     2017  Disparity in Health Status  11.0   25.1
# 10911      Alaska     2017  Disparity in Health Status   1.0   11.1
# 10912     Arizona     2017  Disparity in Health Status  21.0   28.0
# 10913    Arkansas     2017  Disparity in Health Status  14.0   25.5
# 10914  California     2017  Disparity in Health Status  49.0   36.3

# %%
Disparity.rename(columns = {'Rank' : 'Disparity_in_Health_Status_Rank', 
                             'Value' : 'Disparity_in_Health_Status_Value',
                           'State Name': 'State',
                           'Edition': 'Year'}, 
                  inplace = True)
# Out:
# C:\Users\steph\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
Disparity.head()
# Out:
#             State  Year                Measure Name  \
# 10910     Alabama  2017  Disparity in Health Status
# 10911      Alaska  2017  Disparity in Health Status
# 10912     Arizona  2017  Disparity in Health Status
# 10913    Arkansas  2017  Disparity in Health Status
# 10914  California  2017  Disparity in Health Status
#
#        Disparity_in_Health_Status_Rank  Disparity_in_Health_Status_Value
# 10910                             11.0                              25.1
# 10911                              1.0                              11.1
# 10912                             21.0                              28.0
# 10913                             14.0                              25.5
# 10914                             49.0                              36.3

# %%
Disparity = Disparity.drop('Measure Name',axis=1)

# %%
Disparity.head()
# Out:
#             State  Year  Disparity_in_Health_Status_Rank  \
# 10910     Alabama  2017                             11.0
# 10911      Alaska  2017                              1.0
# 10912     Arizona  2017                             21.0
# 10913    Arkansas  2017                             14.0
# 10914  California  2017                             49.0
#
#        Disparity_in_Health_Status_Value
# 10910                              25.1
# 10911                              11.1
# 10912                              28.0
# 10913                              25.5
# 10914                              36.3

# %%
Disparity.to_csv(os.path.join("..","..","Data","Raw","America_Health_Rankings","2017 MidStep","Disparity_in_Health_Status.csv"),index = False)
