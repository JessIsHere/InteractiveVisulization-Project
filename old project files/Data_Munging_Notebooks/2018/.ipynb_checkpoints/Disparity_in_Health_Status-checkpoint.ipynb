# %%
import pandas as pd
from datetime import datetime
import os
import numpy as np

# %%
file = pd.read_csv(os.path.join("..","..","Data","Raw","America_Health_Rankings","2018-Annual.csv"))
print(file)
# Out:
#        Edition  Report Type                   Measure Name  \
# 0         2018  2018 Annual  Adverse Childhood Experiences
# 1         2018  2018 Annual  Adverse Childhood Experiences
# 2         2018  2018 Annual  Adverse Childhood Experiences
# 3         2018  2018 Annual  Adverse Childhood Experiences
# 4         2018  2018 Annual  Adverse Childhood Experiences
# 5         2018  2018 Annual  Adverse Childhood Experiences
# 6         2018  2018 Annual  Adverse Childhood Experiences
# 7         2018  2018 Annual  Adverse Childhood Experiences
# 8         2018  2018 Annual  Adverse Childhood Experiences
# 9         2018  2018 Annual  Adverse Childhood Experiences
# 10        2018  2018 Annual  Adverse Childhood Experiences
# 11        2018  2018 Annual  Adverse Childhood Experiences
# 12        2018  2018 Annual  Adverse Childhood Experiences
# 13        2018  2018 Annual  Adverse Childhood Experiences
# 14        2018  2018 Annual  Adverse Childhood Experiences
# ...

# %%
df2018 = pd.DataFrame(file)
df2018.head()
# Out:
#    Edition  Report Type                   Measure Name     State Name  Rank  \
# 0     2018  2018 Annual  Adverse Childhood Experiences         Alaska  28.0
# 1     2018  2018 Annual  Adverse Childhood Experiences        Alabama  46.0
# 2     2018  2018 Annual  Adverse Childhood Experiences  United States   NaN
# 3     2018  2018 Annual  Adverse Childhood Experiences       Arkansas  49.0
# 4     2018  2018 Annual  Adverse Childhood Experiences        Arizona  50.0
#
#    Value  Score  Lower CI  Upper CI  \
# 0   23.8   0.53       NaN       NaN
# 1   27.7   1.51       NaN       NaN
# 2   21.7    NaN       NaN       NaN
# 3   29.6   1.98       NaN       NaN
# 4   30.6   2.00       NaN       NaN
#
#                                               Source Source Year
# 0  Child and Adolescent Health Measurement Initia...        2016
# 1  Child and Adolescent Health Measurement Initia...        2016
# 2  Child and Adolescent Health Measurement Initia...        2016
# ...

# %%
df2018.count()
# Out:
# Edition         39918
# Report Type     39918
# Measure Name    39918
# State Name      39918
# Rank            22844
# Value           34131
# Score           21354
# Lower CI        36091
# Upper CI        36091
# Source          39918
# Source Year     39662
# dtype: int64

# %%
df2018['Measure Name'].unique()
# Out:
# array(['Adverse Childhood Experiences', 'Air Pollution',
#        'All Determinants', 'All Outcomes', 'Behaviors', 'Binge Drinking',
#        'Binge Drinking - $25-$49,999', 'Binge Drinking - $50-$74,999',
#        'Binge Drinking - $75,000 or More', 'Binge Drinking - Ages 18-44',
#        'Binge Drinking - Ages 45-64', 'Binge Drinking - Ages 65+',
#        'Binge Drinking - American Indian/Alaskan Native',
#        'Binge Drinking - Asian', 'Binge Drinking - Black',
#        'Binge Drinking - College Grad', 'Binge Drinking - Female',
#        'Binge Drinking - Hawaiian/Pacific Islander',
#        'Binge Drinking - High School Grad', 'Binge Drinking - Hispanic',
#        'Binge Drinking - Less Than $25,000',
#        'Binge Drinking - Less Than High School', 'Binge Drinking - Male',
#        'Binge Drinking - Multiracial', 'Binge Drinking - Other Race',
#        'Binge Drinking - Rural', 'Binge Drinking - Some College',
#        'Binge Drinking - Suburban', 'Binge Drinking - Urban',
# ...

# %%
#'Below poverty threshold','Cancer Deaths','Cardiovascular Deaths','Cholesterol Check','Diabetes','Drug Deaths',

# %%
Disparity=df2018[df2018['Measure Name']=='Disparity in Health Status']

# %%
Disparity.head()
# Out:
#        Edition  Report Type                Measure Name  State Name  Rank  \
# 11170     2018  2018 Annual  Disparity in Health Status     Alabama   9.0
# 11171     2018  2018 Annual  Disparity in Health Status      Alaska   1.0
# 11172     2018  2018 Annual  Disparity in Health Status     Arizona  32.0
# 11173     2018  2018 Annual  Disparity in Health Status    Arkansas   5.0
# 11174     2018  2018 Annual  Disparity in Health Status  California  50.0
#
#        Value  Score  Lower CI  Upper CI  \
# 11170   23.1  -1.37       NaN       NaN
# 11171   13.1  -2.00       NaN       NaN
# 11172   29.2  -0.14       NaN       NaN
# 11173   21.2  -1.75       NaN       NaN
# 11174   37.1   1.45       NaN       NaN
#
#                                                 Source Source Year
# 11170  CDC, Behavioral Risk Factor Surveillance System        2017
# 11171  CDC, Behavioral Risk Factor Surveillance System        2017
# 11172  CDC, Behavioral Risk Factor Surveillance System        2017
# ...

# %%
Disparity.isnull().any()
# Out:
# Edition         False
# Report Type     False
# Measure Name    False
# State Name      False
# Rank             True
# Value           False
# Score            True
# Lower CI         True
# Upper CI         True
# Source          False
# Source Year     False
# dtype: bool

# %%
Disparity.loc[Disparity.isnull().any(axis=1)]
# Out:
#        Edition  Report Type                Measure Name            State Name  \
# 11170     2018  2018 Annual  Disparity in Health Status               Alabama
# 11171     2018  2018 Annual  Disparity in Health Status                Alaska
# 11172     2018  2018 Annual  Disparity in Health Status               Arizona
# 11173     2018  2018 Annual  Disparity in Health Status              Arkansas
# 11174     2018  2018 Annual  Disparity in Health Status            California
# 11175     2018  2018 Annual  Disparity in Health Status              Colorado
# 11176     2018  2018 Annual  Disparity in Health Status           Connecticut
# 11177     2018  2018 Annual  Disparity in Health Status              Delaware
# 11178     2018  2018 Annual  Disparity in Health Status               Florida
# 11179     2018  2018 Annual  Disparity in Health Status               Georgia
# 11180     2018  2018 Annual  Disparity in Health Status                Hawaii
# ...

# %%
Disparity = Disparity.fillna(value=0)
Disparity
# Out:
#        Edition  Report Type                Measure Name            State Name  \
# 11170     2018  2018 Annual  Disparity in Health Status               Alabama
# 11171     2018  2018 Annual  Disparity in Health Status                Alaska
# 11172     2018  2018 Annual  Disparity in Health Status               Arizona
# 11173     2018  2018 Annual  Disparity in Health Status              Arkansas
# 11174     2018  2018 Annual  Disparity in Health Status            California
# 11175     2018  2018 Annual  Disparity in Health Status              Colorado
# 11176     2018  2018 Annual  Disparity in Health Status           Connecticut
# 11177     2018  2018 Annual  Disparity in Health Status              Delaware
# 11178     2018  2018 Annual  Disparity in Health Status               Florida
# 11179     2018  2018 Annual  Disparity in Health Status               Georgia
# 11180     2018  2018 Annual  Disparity in Health Status                Hawaii
# ...

# %%
Disparity.count()
# Out:
# Edition         52
# Report Type     52
# Measure Name    52
# State Name      52
# Rank            52
# Value           52
# Score           52
# Lower CI        52
# Upper CI        52
# Source          52
# Source Year     52
# dtype: int64

# %%
list(Disparity.columns.values)
# Out:
# ['Edition',
#  'Report Type',
#  'Measure Name',
#  'State Name',
#  'Rank',
#  'Value',
#  'Score',
#  'Lower CI',
#  'Upper CI',
#  'Source',
#  'Source Year']

# %%
Disparity = Disparity[["State Name",
                                "Edition", 
                              "Measure Name",
                              "Rank",
                              "Value"]]

# %%
Disparity.head()
# Out:
#        State Name  Edition                Measure Name  Rank  Value
# 11170     Alabama     2018  Disparity in Health Status   9.0   23.1
# 11171      Alaska     2018  Disparity in Health Status   1.0   13.1
# 11172     Arizona     2018  Disparity in Health Status  32.0   29.2
# 11173    Arkansas     2018  Disparity in Health Status   5.0   21.2
# 11174  California     2018  Disparity in Health Status  50.0   37.1

# %%
Disparity.rename(columns = {'Rank' : 'Disparity_in_Health_Status_Rank', 
                             'Value' : 'Disparity_in_Health_Status_Value',
                           'State Name': 'State',
                           'Edition': 'Year'}, 
                  inplace = True)
# Out:
# C:\Users\steph\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
Disparity.head()
# Out:
#             State  Year                Measure Name  \
# 11170     Alabama  2018  Disparity in Health Status
# 11171      Alaska  2018  Disparity in Health Status
# 11172     Arizona  2018  Disparity in Health Status
# 11173    Arkansas  2018  Disparity in Health Status
# 11174  California  2018  Disparity in Health Status
#
#        Disparity_in_Health_Status_Rank  Disparity_in_Health_Status_Value
# 11170                              9.0                              23.1
# 11171                              1.0                              13.1
# 11172                             32.0                              29.2
# 11173                              5.0                              21.2
# 11174                             50.0                              37.1

# %%
Disparity = Disparity.drop('Measure Name',axis=1)

# %%
Disparity.head()
# Out:
#             State  Year  Disparity_in_Health_Status_Rank  \
# 11170     Alabama  2018                              9.0
# 11171      Alaska  2018                              1.0
# 11172     Arizona  2018                             32.0
# 11173    Arkansas  2018                              5.0
# 11174  California  2018                             50.0
#
#        Disparity_in_Health_Status_Value
# 11170                              23.1
# 11171                              13.1
# 11172                              29.2
# 11173                              21.2
# 11174                              37.1

# %%
Disparity.to_csv(os.path.join("..","..","Data","Raw","America_Health_Rankings","2018 MidStep","Disparity_in_Health_Status.csv"),index = False)
