# %%
import pandas as pd
from datetime import datetime
import os
import numpy as np

# %%
file = pd.read_csv(os.path.join("Data","Raw","America_Health_Rankings","2019-Annual.csv"))
print(file)
# Out:
#        Edition  Report Type                   Measure Name  \
# 0         2019  2019 Annual  Adverse Childhood Experiences
# 1         2019  2019 Annual  Adverse Childhood Experiences
# 2         2019  2019 Annual  Adverse Childhood Experiences
# 3         2019  2019 Annual  Adverse Childhood Experiences
# 4         2019  2019 Annual  Adverse Childhood Experiences
# 5         2019  2019 Annual  Adverse Childhood Experiences
# 6         2019  2019 Annual  Adverse Childhood Experiences
# 7         2019  2019 Annual  Adverse Childhood Experiences
# 8         2019  2019 Annual  Adverse Childhood Experiences
# 9         2019  2019 Annual  Adverse Childhood Experiences
# 10        2019  2019 Annual  Adverse Childhood Experiences
# 11        2019  2019 Annual  Adverse Childhood Experiences
# 12        2019  2019 Annual  Adverse Childhood Experiences
# 13        2019  2019 Annual  Adverse Childhood Experiences
# 14        2019  2019 Annual  Adverse Childhood Experiences
# ...

# %%
df2019 = pd.DataFrame(file)
df2019.head()
# Out:
#    Edition  Report Type                   Measure Name     State Name  Rank  \
# 0     2019  2019 Annual  Adverse Childhood Experiences         Alaska  34.0
# 1     2019  2019 Annual  Adverse Childhood Experiences        Alabama  46.0
# 2     2019  2019 Annual  Adverse Childhood Experiences  United States   NaN
# 3     2019  2019 Annual  Adverse Childhood Experiences       Arkansas  47.0
# 4     2019  2019 Annual  Adverse Childhood Experiences        Arizona  48.0
#
#    Value  Score  Lower CI  Upper CI  \
# 0   24.1   0.96      27.7      20.5
# 1   26.3   1.56      30.1      22.5
# 2   20.5    NaN      21.2      19.8
# 3   27.1   1.76      30.8      23.3
# 4   27.3   1.82      31.1      23.4
#
#                                               Source Source Year
# 0  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# 1  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# 2  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# ...

# %%
df2019.count()
# Out:
# Edition         32642
# Report Type     32642
# Measure Name    32642
# State Name      32642
# Rank            18950
# Value           27576
# Score           16803
# Lower CI        26006
# Upper CI        26006
# Source          32642
# Source Year     32486
# dtype: int64

# %%
df2019['Measure Name'].unique()
# Out:
# array(['Adverse Childhood Experiences', 'Air Pollution',
#        'All Determinants', 'All Outcomes', 'Behaviors',
#        'Below poverty threshold', 'Cancer Deaths',
#        'Cancer Deaths - American Indian/Alaska Native',
#        'Cancer Deaths - Asian/Pacific Islander',
#        'Cancer Deaths - Black/African American',
#        'Cancer Deaths - Crude Rate', 'Cancer Deaths - Female',
#        'Cancer Deaths - Hispanic/Latino', 'Cancer Deaths - Male',
#        'Cancer Deaths - Standard Age Adjustment', 'Cancer Deaths - White',
#        'Cardiovascular Deaths',
#        'Cardiovascular Deaths - American Indian/Alaska Native',
#        'Cardiovascular Deaths - Asian/Pacific Islander',
#        'Cardiovascular Deaths - Black/African American',
#        'Cardiovascular Deaths - Crude Rate',
#        'Cardiovascular Deaths - Female',
#        'Cardiovascular Deaths - Hispanic/Latino',
#        'Cardiovascular Deaths - Male',
# ...

# %%
#'Below poverty threshold','Cancer Deaths','Cardiovascular Deaths','Cholesterol Check','Diabetes','Drug Deaths',

# %%
Cancer_Deaths=df2019[df2019['Measure Name']=='Cancer Deaths']

# %%
Cancer_Deaths.head()
# Out:
#      Edition  Report Type   Measure Name  State Name  Rank  Value  Score  \
# 306     2019  2019 Annual  Cancer Deaths     Alabama  42.0  210.8   1.19
# 307     2019  2019 Annual  Cancer Deaths      Alaska  18.0  185.4  -0.22
# 308     2019  2019 Annual  Cancer Deaths     Arizona   4.0  168.5  -1.15
# 309     2019  2019 Annual  Cancer Deaths    Arkansas  46.0  217.7   1.58
# 310     2019  2019 Annual  Cancer Deaths  California   5.0  168.9  -1.13
#
#      Lower CI  Upper CI                                             Source  \
# 306     213.1     208.4  CDC WONDER Online Database, Underlying Cause o...
# 307     192.4     178.5  CDC WONDER Online Database, Underlying Cause o...
# 308     170.3     166.8  CDC WONDER Online Database, Underlying Cause o...
# 309     220.7     214.7  CDC WONDER Online Database, Underlying Cause o...
# 310     169.7     168.2  CDC WONDER Online Database, Underlying Cause o...
#
#     Source Year
# 306   2015-2017
# 307   2015-2017
# 308   2015-2017
# ...

# %%
Cancer_Deaths.isnull().any()
# Out:
# Edition         False
# Report Type     False
# Measure Name    False
# State Name      False
# Rank             True
# Value           False
# Score            True
# Lower CI        False
# Upper CI        False
# Source          False
# Source Year     False
# dtype: bool

# %%
Cancer_Deaths.loc[Cancer_Deaths.isnull().any(axis=1)]
# Out:
#      Edition  Report Type   Measure Name            State Name  Rank  Value  \
# 356     2019  2019 Annual  Cancer Deaths         United States   NaN  189.3
# 357     2019  2019 Annual  Cancer Deaths  District of Columbia   NaN  195.7
#
#      Score  Lower CI  Upper CI  \
# 356    NaN     189.6     189.0
# 357    NaN     202.5     188.9
#
#                                                 Source Source Year
# 356  CDC WONDER Online Database, Underlying Cause o...   2015-2017
# 357  CDC WONDER Online Database, Underlying Cause o...   2015-2017

# %%
Cancer_Deaths = Cancer_Deaths.fillna(value=0)
Cancer_Deaths
# Out:
#      Edition  Report Type   Measure Name            State Name  Rank  Value  \
# 306     2019  2019 Annual  Cancer Deaths               Alabama  42.0  210.8
# 307     2019  2019 Annual  Cancer Deaths                Alaska  18.0  185.4
# 308     2019  2019 Annual  Cancer Deaths               Arizona   4.0  168.5
# 309     2019  2019 Annual  Cancer Deaths              Arkansas  46.0  217.7
# 310     2019  2019 Annual  Cancer Deaths            California   5.0  168.9
# 311     2019  2019 Annual  Cancer Deaths              Colorado   3.0  163.1
# 312     2019  2019 Annual  Cancer Deaths           Connecticut   8.0  174.2
# 313     2019  2019 Annual  Cancer Deaths              Delaware  37.0  201.3
# 314     2019  2019 Annual  Cancer Deaths               Florida  13.0  181.1
# 315     2019  2019 Annual  Cancer Deaths               Georgia  30.0  194.8
# 316     2019  2019 Annual  Cancer Deaths                Hawaii   2.0  159.1
# ...

# %%
Cancer_Deaths.count()
# Out:
# Edition         52
# Report Type     52
# Measure Name    52
# State Name      52
# Rank            52
# Value           52
# Score           52
# Lower CI        52
# Upper CI        52
# Source          52
# Source Year     52
# dtype: int64

# %%
list(Cancer_Deaths.columns.values)
# Out:
# ['Edition',
#  'Report Type',
#  'Measure Name',
#  'State Name',
#  'Rank',
#  'Value',
#  'Score',
#  'Lower CI',
#  'Upper CI',
#  'Source',
#  'Source Year']

# %%
Cancer_Deaths = Cancer_Deaths[["State Name",
            "Edition", 
            "Measure Name",
            "Rank",
            "Value"]]

# %%
Cancer_Deaths.head()
# Out:
#      State Name  Edition   Measure Name  Rank  Value
# 306     Alabama     2019  Cancer Deaths  42.0  210.8
# 307      Alaska     2019  Cancer Deaths  18.0  185.4
# 308     Arizona     2019  Cancer Deaths   4.0  168.5
# 309    Arkansas     2019  Cancer Deaths  46.0  217.7
# 310  California     2019  Cancer Deaths   5.0  168.9

# %%
Cancer_Deaths.rename(columns = {'Rank' : 'Cancer_Deaths_Rank', 
                             'Value' : 'Cancer_Deaths_Value',
                             'State Name': 'State',
                             'Edition': 'Year'}, 
                  inplace = True)
# Out:
# C:\Users\steph\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
Cancer_Deaths.head()
# Out:
#           State  Year   Measure Name  Cancer_Deaths_Rank  Cancer_Deaths_Value
# 306     Alabama  2019  Cancer Deaths                42.0                210.8
# 307      Alaska  2019  Cancer Deaths                18.0                185.4
# 308     Arizona  2019  Cancer Deaths                 4.0                168.5
# 309    Arkansas  2019  Cancer Deaths                46.0                217.7
# 310  California  2019  Cancer Deaths                 5.0                168.9

# %%
Cancer_Deaths = Cancer_Deaths.drop('Measure Name',axis=1)

# %%
Cancer_Deaths.head()
# Out:
#           State  Year  Cancer_Deaths_Rank  Cancer_Deaths_Value
# 306     Alabama  2019                42.0                210.8
# 307      Alaska  2019                18.0                185.4
# 308     Arizona  2019                 4.0                168.5
# 309    Arkansas  2019                46.0                217.7
# 310  California  2019                 5.0                168.9

# %%
Cancer_Deaths.to_csv(os.path.join("Data","Raw","America_Health_Rankings","2019 MidStep","Cancer_Deaths.csv"),index = False)
