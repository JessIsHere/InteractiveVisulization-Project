# %%
import pandas as pd
from datetime import datetime
import os
import numpy as np

# %%
file = pd.read_csv(os.path.join("..","..","Data","Raw","America_Health_Rankings","2017-Annual.csv"))
print(file)
# Out:
#        Edition  Report Type        Measure Name      State Name  Rank  Value  \
# 0         2017  2017 Annual       Air Pollution          Alaska  36.0    8.7
# 1         2017  2017 Annual       Air Pollution         Alabama  39.0    8.9
# 2         2017  2017 Annual       Air Pollution        Arkansas  16.0    7.2
# 3         2017  2017 Annual       Air Pollution         Arizona  46.0    9.7
# 4         2017  2017 Annual       Air Pollution      California  50.0   11.7
# 5         2017  2017 Annual       Air Pollution        Colorado  12.0    6.6
# 6         2017  2017 Annual       Air Pollution     Connecticut  35.0    8.6
# 7         2017  2017 Annual       Air Pollution        Delaware  43.0    9.1
# 8         2017  2017 Annual       Air Pollution         Florida  13.0    6.8
# 9         2017  2017 Annual       Air Pollution         Georgia  41.0    9.0
# 10        2017  2017 Annual       Air Pollution          Hawaii   6.0    5.9
# ...

# %%
df2017 = pd.DataFrame(file)
df2017.head()
# Out:
#    Edition  Report Type   Measure Name  State Name  Rank  Value  Score  \
# 0     2017  2017 Annual  Air Pollution      Alaska  36.0    8.7   0.06
# 1     2017  2017 Annual  Air Pollution     Alabama  39.0    8.9   0.19
# 2     2017  2017 Annual  Air Pollution    Arkansas  16.0    7.2  -0.90
# 3     2017  2017 Annual  Air Pollution     Arizona  46.0    9.7   0.71
# 4     2017  2017 Annual  Air Pollution  California  50.0   11.7   2.00
#
#    Lower CI  Upper CI                                             Source  \
# 0       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 1       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 2       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 3       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 4       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
#
#   Source Year
# 0   2014-2016
# 1   2014-2016
# 2   2014-2016
# 3   2014-2016
# 4   2014-2016

# %%
df2017.count()
# Out:
# Edition         37738
# Report Type     37738
# Measure Name    37738
# State Name      37738
# Rank            31308
# Value           32122
# Score           31156
# Lower CI        34409
# Upper CI        34409
# Source          37738
# Source Year     37322
# dtype: int64

# %%
df2017['Measure Name'].unique()
# Out:
# array(['Air Pollution', 'All Determinants', 'All Outcomes', 'Behaviors',
#        'Binge Drinking', 'Binge Drinking - $25-$49,999',
#        'Binge Drinking - $50-$74,999', 'Binge Drinking - $75,000 or More',
#        'Binge Drinking - Ages 18-44', 'Binge Drinking - Ages 45-64',
#        'Binge Drinking - Ages 65+',
#        'Binge Drinking - American Indian/Alaskan Native',
#        'Binge Drinking - Asian', 'Binge Drinking - Black',
#        'Binge Drinking - College Grad', 'Binge Drinking - Female',
#        'Binge Drinking - Hawaiian/Pacific Islander',
#        'Binge Drinking - High School Grad', 'Binge Drinking - Hispanic',
#        'Binge Drinking - Less Than $25,000',
#        'Binge Drinking - Less Than High School', 'Binge Drinking - Male',
#        'Binge Drinking - Multiracial', 'Binge Drinking - Other Race',
#        'Binge Drinking - Rural', 'Binge Drinking - Some College',
#        'Binge Drinking - Suburban', 'Binge Drinking - Urban',
# ...

# %%
#'Below poverty threshold','Cancer Deaths','Cardiovascular Deaths','Cholesterol Check','Diabetes','Drug Deaths',

# %%
PCP=df2017[df2017['Measure Name']=='Primary Care Physicians']

# %%
PCP.head()
# Out:
#        Edition  Report Type             Measure Name  State Name  Rank  Value  \
# 30718     2017  2017 Annual  Primary Care Physicians      Alaska  30.0  133.7
# 30719     2017  2017 Annual  Primary Care Physicians     Alabama  42.0  119.3
# 30720     2017  2017 Annual  Primary Care Physicians    Arkansas  43.0  115.4
# 30721     2017  2017 Annual  Primary Care Physicians     Arizona  37.0  126.0
# 30722     2017  2017 Annual  Primary Care Physicians  California  29.0  135.1
#
#        Score  Lower CI  Upper CI  \
# 30718  -0.46       NaN       NaN
# 30719  -0.87       NaN       NaN
# 30720  -0.98       NaN       NaN
# 30721  -0.68       NaN       NaN
# 30722  -0.42       NaN       NaN
#
#                                                   Source Source Year
# 30718  Special data request for information on active...        2017
# 30719  Special data request for information on active...        2017
# 30720  Special data request for information on active...        2017
# ...

# %%
PCP.isnull().any()
# Out:
# Edition         False
# Report Type     False
# Measure Name    False
# State Name      False
# Rank             True
# Value           False
# Score            True
# Lower CI         True
# Upper CI         True
# Source          False
# Source Year     False
# dtype: bool

# %%
PCP.loc[PCP.isnull().any(axis=1)]
# Out:
#        Edition  Report Type             Measure Name            State Name  \
# 30718     2017  2017 Annual  Primary Care Physicians                Alaska
# 30719     2017  2017 Annual  Primary Care Physicians               Alabama
# 30720     2017  2017 Annual  Primary Care Physicians              Arkansas
# 30721     2017  2017 Annual  Primary Care Physicians               Arizona
# 30722     2017  2017 Annual  Primary Care Physicians            California
# 30723     2017  2017 Annual  Primary Care Physicians              Colorado
# 30724     2017  2017 Annual  Primary Care Physicians           Connecticut
# 30725     2017  2017 Annual  Primary Care Physicians              Delaware
# 30726     2017  2017 Annual  Primary Care Physicians               Florida
# 30727     2017  2017 Annual  Primary Care Physicians               Georgia
# 30728     2017  2017 Annual  Primary Care Physicians                Hawaii
# ...

# %%
PCP = PCP.fillna(value=0)
PCP
# Out:
#        Edition  Report Type             Measure Name            State Name  \
# 30718     2017  2017 Annual  Primary Care Physicians                Alaska
# 30719     2017  2017 Annual  Primary Care Physicians               Alabama
# 30720     2017  2017 Annual  Primary Care Physicians              Arkansas
# 30721     2017  2017 Annual  Primary Care Physicians               Arizona
# 30722     2017  2017 Annual  Primary Care Physicians            California
# 30723     2017  2017 Annual  Primary Care Physicians              Colorado
# 30724     2017  2017 Annual  Primary Care Physicians           Connecticut
# 30725     2017  2017 Annual  Primary Care Physicians              Delaware
# 30726     2017  2017 Annual  Primary Care Physicians               Florida
# 30727     2017  2017 Annual  Primary Care Physicians               Georgia
# 30728     2017  2017 Annual  Primary Care Physicians                Hawaii
# ...

# %%
PCP.count()
# Out:
# Edition         52
# Report Type     52
# Measure Name    52
# State Name      52
# Rank            52
# Value           52
# Score           52
# Lower CI        52
# Upper CI        52
# Source          52
# Source Year     52
# dtype: int64

# %%
list(PCP.columns.values)
# Out:
# ['Edition',
#  'Report Type',
#  'Measure Name',
#  'State Name',
#  'Rank',
#  'Value',
#  'Score',
#  'Lower CI',
#  'Upper CI',
#  'Source',
#  'Source Year']

# %%
PCP = PCP[["State Name",
            "Edition", 
            "Measure Name",
            "Rank",
            "Value"]]

# %%
PCP.head()
# Out:
#        State Name  Edition             Measure Name  Rank  Value
# 30718      Alaska     2017  Primary Care Physicians  30.0  133.7
# 30719     Alabama     2017  Primary Care Physicians  42.0  119.3
# 30720    Arkansas     2017  Primary Care Physicians  43.0  115.4
# 30721     Arizona     2017  Primary Care Physicians  37.0  126.0
# 30722  California     2017  Primary Care Physicians  29.0  135.1

# %%
PCP.rename(columns = {'Rank' : 'Primary_Care_Physicians_Rank', 
                             'Value' : 'Primary_Care_Physicians_Value',
                             'State Name': 'State',
                             'Edition': 'Year'}, 
                  inplace = True)
# Out:
# C:\Users\steph\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
PCP.head()
# Out:
#             State  Year             Measure Name  \
# 30718      Alaska  2017  Primary Care Physicians
# 30719     Alabama  2017  Primary Care Physicians
# 30720    Arkansas  2017  Primary Care Physicians
# 30721     Arizona  2017  Primary Care Physicians
# 30722  California  2017  Primary Care Physicians
#
#        Primary_Care_Physicians_Rank  Primary_Care_Physicians_Value
# 30718                          30.0                          133.7
# 30719                          42.0                          119.3
# 30720                          43.0                          115.4
# 30721                          37.0                          126.0
# 30722                          29.0                          135.1

# %%
PCP = PCP.drop('Measure Name',axis=1)

# %%
PCP.head()
# Out:
#             State  Year  Primary_Care_Physicians_Rank  \
# 30718      Alaska  2017                          30.0
# 30719     Alabama  2017                          42.0
# 30720    Arkansas  2017                          43.0
# 30721     Arizona  2017                          37.0
# 30722  California  2017                          29.0
#
#        Primary_Care_Physicians_Value
# 30718                          133.7
# 30719                          119.3
# 30720                          115.4
# 30721                          126.0
# 30722                          135.1

# %%
PCP.to_csv(os.path.join("..","..","Data","Raw","America_Health_Rankings","2017 MidStep","Primary_Care_Physicians.csv"),index = False)
